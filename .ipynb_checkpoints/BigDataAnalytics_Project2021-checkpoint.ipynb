# %% [markdown]
# # Big Data Analytics - Project - 2021

# %% [markdown]
# ### Authors: Kirill ??, Lilith Feer, Luca ??, Mark ??, Remo ??
# ### Matrikel-Nr.: ???, 16720799, ???, ???, ???

# %% [markdown]
# ## Goal
#
# ### Goal Description

# %% [markdown]
# #

# %% [markdown]
# ## Packages & Libraries

# %%
#install.packages("BiocManager")
#BiocManager::install("Rgraphviz")

#install.packages('CePa', .libPaths(), repos='http://cran.us.r-project.org')
# or
#BiocManager::install("cmapR")


#install.packages("data.table")
#install.packages("dplyr")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# '?repositories' for details
#
# replacement repositories:
#     CRAN: https://cran.r-project.org
#
#
# Bioconductor version 3.12 (BiocManager 1.30.15), R 4.0.4 (2021-02-15)
#
# Installing package(s) 'CmapR'
#
# Warning message in .inet_warning(msg):
# "package 'CmapR' is not available for Bioconductor version '3.12'
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages"
# Warning message in .inet_warning(msg):
# "Perhaps you meant 'cmapR' ?"
# Installation paths not writeable, unable to update packages
#   path: C:/Program Files/R/R-4.0.4/library
#   packages:
#     boot, class, cluster, KernSmooth, lattice, MASS, Matrix, mgcv, nnet,
#     spatial, survival
#
# Old packages: 'colorspace', 'curl', 'dplyr', 'ellipsis', 'haven', 'installr',
#   'openssl', 'processx', 'raster', 'rlang', 'rmarkdown', 'statmod', 'stringi',
#   'tibble', 'tidyselect', 'vctrs', 'viridis', 'xfun'

# %%
library(ggplot2)
#library(CePa)
library(data.table)
library("dplyr") 
library(cmapR)

# %% [markdown]
# ## Dataset
# ### Description:
# #### Pancreatic cancer arises from the abnormal and uncontrolled growth of cells in the tissues of the pancreas. Pancreatic adenocarcinoma (PAAD) is the most common type of pancreatic cancer, accounting for approximately 85% of all types of pancreatic cancer. This cancer is the twelfth most common cancer and the seventh leading cause of cancer-related death. [01]
#
# #### The dataset contains normalized RNA Sequencing reads for pancreatic cancer tumors. The measurement consists of ~20,000 genes for 185 pancreatic cancer tumors. The file format is GCT , a tab-delimited file used for sharing gene expression data and metadata (details for each sample) for samples.
#
# ### Link:
# ### https://www.kaggle.com/abhiparashar/cancer-prediction?select=PAAD.gct
#
# ### Load:

# %%
# 1 -  Read gct:
# original_dataset <- read.gct("Data/PAAD.gct")

# 2 - Read in data.table format:                    # Setting Participant ID as column Name -> skip = 3
original_dataset <- fread("Data/PAAD.gct", skip = 3, quote = "", header = TRUE, sep = "\t")

# %%
# Dimensions of the dataset
dim(original_dataset)

# Overview of types of Data
#str(original_dataset)

# Patients IDs
patients_IDs <- colnames(original_dataset)

# Features
rownames <- original_dataset[,1]

# Attributes
#attributes(original_dataset)

head(original_dataset,20)
# Out:
# [1] 18588   184
#    participant_id                        aab1
# 1  sample_type                           Primary solid Tumor
# 2  mRNAseq_cluster                       1
# 3  bcr_patient_barcode                   tcga-2j-aab1
# 4  bcr_patient_uuid                      75119d1a-93e5-4ae7-9d60-69ee929a0772
# 5  vital_status                          dead
# 6  days_to_death                         66
# 7  days_to_last_followup                 NA
# 8  additional_studies                    NA
# 9  adenocarcinoma_invasion               yes
# 10 age_at_initial_pathologic_diagnosis   65
# 11 alcohol_history_documented            yes
# 12 alcoholic_exposure_category           weekly drinker
# 13 amount_of_alcohol_consumption_per_day 1
# 14 anatomic_neoplasm_subdivision         head of pancreas
# 15 anatomic_neoplasm_subdivision_other   NA
# 16 b_symptoms                            NA
# 17 bcr                                   nationwide children's hospital
# 18 bcr_aliquot_uuid                      d3f960b2-c69d-4b64-a30f-72f4fa7bb2f9
# 19 bcr_canonical_reason-2                NA
# 20 bcr_canonical_reason-3                NA
#    aab4                                 aab6
# 1  Primary solid Tumor                  Primary solid Tumor
# 2  2                                    3
# 3  tcga-2j-aab4                         tcga-2j-aab6
# 4  33833131-1482-42d5-9cf5-01cade540234 70797499-16e6-48cc-8ae4-1e692713dad3
# 5  alive                                dead
# 6  NA                                   293
# 7  729                                  NA
# 8  NA                                   NA
# 9  yes                                  yes
# 10 48                                   75
# 11 no                                   no
# 12 NA                                   NA
# 13 NA                                   NA
# 14 other (please specify)               body of pancreas
# 15 body & tail of pancreas              NA
# 16 NA                                   NA
# 17 nationwide children's hospital       nationwide children's hospital
# 18 9daae9d7-747e-44e0-a8f8-3c3f9e3f03f3 c850368e-6e95-4879-8245-205ddeec6fbd
# 19 NA                                   NA
# 20 NA                                   NA
#    aab8                                 aab9
# 1  Primary solid Tumor                  Primary solid Tumor
# 2  1                                    4
# 3  tcga-2j-aab8                         tcga-2j-aab9
# 4  2e8f90f4-aed3-43b0-985c-dfdc2581f24f a5748656-5330-417a-8938-01f69ddb3576
# 5  alive                                dead
# 6  NA                                   627
# 7  80                                   NA
# 8  NA                                   NA
# 9  yes                                  yes
# 10 71                                   70
# 11 no                                   yes
# 12 NA                                   weekly drinker
# 13 NA                                   1
# 14 head of pancreas                     head of pancreas
# 15 NA                                   NA
# 16 NA                                   NA
# 17 nationwide children's hospital       nationwide children's hospital
# 18 5749429c-5ac9-40de-b44e-3b795520ec07 be56b07b-cd57-46a0-baa1-e20169d88468
# 19 NA                                   NA
# 20 NA                                   NA
#    aaba                                 aabe
# 1  Primary solid Tumor                  Primary solid Tumor
# 2  3                                    3
# 3  tcga-2j-aaba                         tcga-2j-aabe
# 4  e3a19e63-bae5-498b-9687-41194aa5728d 58c1c391-5ea3-4432-bb1e-e7e1974954bc
# 5  dead                                 alive
# 6  607                                  NA
# 7  NA                                   676
# 8  NA                                   NA
# 9  yes                                  yes
# 10 55                                   73
# 11 no                                   yes
# 12 NA                                   weekly drinker
# 13 NA                                   1
# 14 head of pancreas                     body of pancreas
# 15 NA                                   NA
# 16 NA                                   NA
# 17 nationwide children's hospital       nationwide children's hospital
# 18 4dddd9de-1aed-43bd-853e-f1d0a845680e be93c69f-5cc3-4289-9cb3-79024701026f
# 19 NA                                   NA
# 20 NA                                   NA
#    aabf                                 aabh
# 1  Primary solid Tumor                  Primary solid Tumor
# 2  2                                    2
# 3  tcga-2j-aabf                         tcga-2j-aabh
# 4  886d6116-d496-444f-9b7b-7449dad31055 c53328b4-0930-4e6a-a648-283b5565295e
# 5  dead                                 alive
# 6  691                                  NA
# 7  NA                                   1287
# 8  NA                                   NA
# 9  yes                                  yes
# 10 73                                   61
# 11 yes                                  no
# 12 weekly drinker                       NA
# 13 1                                    NA
# 14 head of pancreas                     body of pancreas
# 15 NA                                   NA
# 16 NA                                   NA
# 17 nationwide children's hospital       nationwide children's hospital
# 18 d4beb2ee-42e9-417d-9ba6-5b9b16c02bae bd0474cb-d20c-4c4f-bb01-136e2c8fea82
# 19 NA                                   NA
# 20 NA                                   NA
#    ... aauh
# 1  ... Primary solid Tumor
# 2  ... 2
# 3  ... tcga-xd-aauh
# 4  ... b46b5a4c-59fc-4769-b05a-d15f9aaa753a
# 5  ... alive
# 6  ... NA
# 7  ... 395
# 8  ... NA
# 9  ... yes
# 10 ... 57
# 11 ... yes
# 12 ... daily drinker
# 13 ... NA
# 14 ... head of pancreas
# 15 ... NA
# 16 ... NA
# 17 ... nationwide children's hospital
# 18 ... 5b6016d8-9650-4fd1-b106-6205343129b4
# 19 ... NA
# 20 ... NA
#    aaui                                 aaul
# 1  Primary solid Tumor                  Primary solid Tumor
# 2  5                                    3
# 3  tcga-xd-aaui                         tcga-xd-aaul
# 4  9a2db69e-d429-45d4-89ca-a2c4e0cfc116 597a5a56-244b-4218-a55d-5d08217ea28c
# 5  dead                                 alive
# 6  366                                  NA
# 7  NA                                   498
# 8  NA                                   NA
# 9  yes                                  yes
# 10 50                                   56
# 11 yes                                  yes
# 12 occasional drinker                   none
# 13 NA                                   NA
# 14 head of pancreas                     head of pancreas
# 15 NA                                   NA
# 16 NA                                   NA
# 17 nationwide children's hospital       nationwide children's hospital
# 18 e5f200b4-1f48-4472-8550-7b1c92d90075 a9badf93-d810-4a9d-b8c6-f566188bbcfa
# 19 NA                                   NA
# 20 NA                                   NA
#    a8t3                                 a8t5
# 1  Primary solid Tumor                  Primary solid Tumor
# 2  4                                    5
# 3  tcga-xn-a8t3                         tcga-xn-a8t5
# 4  dd7bcdd8-1660-4dab-9860-9d136c4cee77 382b279f-87e1-4dbc-a2ca-c1dfde1cf254
# 5  alive                                alive
# 6  NA                                   NA
# 7  951                                  720
# 8  NA                                   NA
# 9  yes                                  yes
# 10 67                                   53
# 11 no                                   no
# 12 NA                                   NA
# 13 NA                                   NA
# 14 head of pancreas                     head of pancreas
# 15 NA                                   NA
# 16 NA                                   NA
# 17 nationwide children's hospital       nationwide children's hospital
# 18 4433e74c-2dad-4206-9a25-519336fe88fa 9b3c88fd-4422-44fd-860e-3d6b3ebfe3d0
# 19 NA                                   NA
# 20 NA                                   NA
#    a89d                                 a89d.1
# 1  Solid Tissue Normal                  Primary solid Tumor
# 2                                       2
# 3  tcga-yb-a89d                         tcga-yb-a89d
# 4  b84b58c7-95b8-4162-8e61-414f8fe422c6 b84b58c7-95b8-4162-8e61-414f8fe422c6
# 5  alive                                alive
# 6  NA                                   NA
# 7  350                                  350
# 8  NA                                   NA
# 9  yes                                  yes
# 10 59                                   59
# 11 no                                   no
# 12 NA                                   NA
# 13 NA                                   NA
# 14 head of pancreas                     head of pancreas
# 15 NA                                   NA
# 16 NA                                   NA
# 17 nationwide children's hospital       nationwide children's hospital
# 18 12ef6f0f-ca63-4139-a4f1-6ad86fc7db61 12ef6f0f-ca63-4139-a4f1-6ad86fc7db61
# 19 case matched methylation control     case matched methylation control
# 20 germline comparison                  germline comparison
#    a8sy                                 a8lh
# 1  Primary solid Tumor                  Primary solid Tumor
# 2  3                                    1
# 3  tcga-yh-a8sy                         tcga-yy-a8lh
# 4  503d7e36-df78-428d-9971-09ff707645c2 ede2e8a7-465e-4725-880d-519899aba0c0
# 5  alive                                alive
# 6  NA                                   NA
# 7  388                                  2016
# 8  NA                                   NA
# 9  yes                                  yes
# 10 73                                   61
# 11 yes                                  yes
# 12 weekly drinker                       occasional drinker
# 13 NA                                   NA
# 14 head of pancreas                     tail of pancreas
# 15 NA                                   NA
# 16 NA                                   NA
# 17 nationwide children's hospital       nationwide children's hospital
# 18 50e76899-a6c1-4e0f-943c-025352a012ec 893dfe82-0fcb-49c5-8d0e-04b112d524f2
# 19 NA                                   NA
# 20 NA                                   NA
#    aapl
# 1  Primary solid Tumor
# 2  5
# 3  tcga-z5-aapl
# 4  6a4e10b6-e6c4-4210-ae4d-0d8e8d0cb3ec
# 5  alive
# 6  NA
# 7  467
# 8  NA
# 9  yes
# 10 74
# 11 NA
# 12 NA
# 13 NA
# 14 other (please specify)
# 15 body and tail
# 16 NA
# 17 nationwide children's hospital
# 18 4304b319-7904-42bb-b278-e5638edbe1a1
# 19 NA
# 20 NA

# %% [markdown]
# ### Separate the two data sets (meta data and expression data)

# %%
Expression_data <- original_dataset[124:length(original_dataset$participant_id),]
Patient_data <- original_dataset[1:123,]
Patient_data
Expression_data
# Out:
#     participant_id
# 1   sample_type
# 2   mRNAseq_cluster
# 3   bcr_patient_barcode
# 4   bcr_patient_uuid
# 5   vital_status
# 6   days_to_death
# 7   days_to_last_followup
# 8   additional_studies
# 9   adenocarcinoma_invasion
# 10  age_at_initial_pathologic_diagnosis
# 11  alcohol_history_documented
# 12  alcoholic_exposure_category
# 13  amount_of_alcohol_consumption_per_day
# 14  anatomic_neoplasm_subdivision
# 15  anatomic_neoplasm_subdivision_other
# 16  b_symptoms
# 17  bcr
# 18  bcr_aliquot_uuid
# 19  bcr_canonical_reason-2
# 20  bcr_canonical_reason-3
# 21  bcr_canonical_reason
# 22  bcr_followup_barcode
# 23  bcr_followup_uuid
# 24  bcr_patient_canonical_status
# 25  clinical_m
# 26  clinical_n
# 27  clinical_stage
# 28  clinical_t
# 29  course_number
# 30  day_of_dcc_upload
# ... ...
# 94  radiation_therapy
# 95  radiation_type_notes
# 96  radiations
# 97  regimen_number
# 98  relative_cancer_type-2
# 99  relative_cancer_type
# 100 residual_tumor
# 101 route_of_administration
# 102 secondary_pattern
# 103 serum_markers
# 104 source_of_patient_death_reason
# 105 stopped_smoking_year
# 106 surgery_performed_type
# 107 system_version
# 108 targeted_molecular_therapy
# 109 tertiary_pattern
# 110 therapy_type_notes
# 111 tissue_prospective_collection_indicator
# 112 tissue_retrospective_collection_indicator
# 113 tissue_source_site
# 114 tobacco_smoking_history
# 115 total_dose
# 116 total_dose_units
# 117 tumor_tissue_site
# 118 tumor_type
# 119 withdrawn
# 120 year_of_dcc_upload
# 121 year_of_form_completion
# 122 year_of_initial_pathologic_diagnosis
# 123 year_of_tobacco_smoking_onset
#     aab1                                 aab4
# 1   Primary solid Tumor                  Primary solid Tumor
# 2   1                                    2
# 3   tcga-2j-aab1                         tcga-2j-aab4
# 4   75119d1a-93e5-4ae7-9d60-69ee929a0772 33833131-1482-42d5-9cf5-01cade540234
# 5   dead                                 alive
# 6   66                                   NA
# 7   NA                                   729
# 8   NA                                   NA
# 9   yes                                  yes
# 10  65                                   48
# 11  yes                                  no
# 12  weekly drinker                       NA
# 13  1                                    NA
# 14  head of pancreas                     other (please specify)
# 15  NA                                   body & tail of pancreas
# 16  NA                                   NA
# 17  nationwide children's hospital       nationwide children's hospital
# 18  d3f960b2-c69d-4b64-a30f-72f4fa7bb2f9 9daae9d7-747e-44e0-a8f8-3c3f9e3f03f3
# 19  NA                                   NA
# 20  NA                                   NA
# 21  NA                                   NA
# 22  NA                                   tcga-2j-aab4-f62444
# 23  NA                                   ce0b8128-82b9-4164-808f-1b4447134f54
# 24  canonical                            canonical
# 25  NA                                   NA
# 26  NA                                   NA
# 27  NA                                   NA
# 28  NA                                   NA
# 29  NA                                   NA
# 30  21                                   21
# ... ...                                  ...
# 94  no                                   no
# 95  NA                                   NA
# 96  NA                                   NA
# 97  NA                                   NA
# 98  NA                                   NA
# 99  NA                                   NA
# 100 r0                                   r0
# 101 NA                                   NA
# 102 NA                                   NA
# 103 NA                                   NA
# 104 medical record                       NA
# 105 1988                                 NA
# 106 whipple                              distal pancreatectomy
# 107 7                                    7
# 108 yes                                  yes
# 109 NA                                   NA
# 110 NA                                   NA
# 111 no                                   no
# 112 yes                                  yes
# 113 2j                                   2j
# 114 3                                    5
# 115 NA                                   NA
# 116 NA                                   NA
# 117 pancreas                             pancreas
# 118 primary                              primary
# 119 false                                false
# 120 2016                                 2016
# 121 2014                                 2014
# 122 2012                                 2012
# 123 1962                                 NA
#     aab6                                 aab8
# 1   Primary solid Tumor                  Primary solid Tumor
# 2   3                                    1
# 3   tcga-2j-aab6                         tcga-2j-aab8
# 4   70797499-16e6-48cc-8ae4-1e692713dad3 2e8f90f4-aed3-43b0-985c-dfdc2581f24f
# 5   dead                                 alive
# 6   293                                  NA
# 7   NA                                   80
# 8   NA                                   NA
# 9   yes                                  yes
# 10  75                                   71
# 11  no                                   no
# 12  NA                                   NA
# 13  NA                                   NA
# 14  body of pancreas                     head of pancreas
# 15  NA                                   NA
# 16  NA                                   NA
# 17  nationwide children's hospital       nationwide children's hospital
# 18  c850368e-6e95-4879-8245-205ddeec6fbd 5749429c-5ac9-40de-b44e-3b795520ec07
# 19  NA                                   NA
# 20  NA                                   NA
# 21  NA                                   NA
# 22  NA                                   tcga-2j-aab8-f62434
# 23  NA                                   daf7d897-0ed7-48ec-ae70-080dd8d7d6bd
# 24  canonical                            canonical
# 25  NA                                   NA
# 26  NA                                   NA
# 27  NA                                   NA
# 28  NA                                   NA
# 29  NA                                   NA
# 30  21                                   21
# ... ...                                  ...
# 94  no                                   NA
# 95  NA                                   NA
# 96  NA                                   NA
# 97  NA                                   NA
# 98  NA                                   NA
# 99  NA                                   NA
# 100 r0                                   r1
# 101 NA                                   NA
# 102 NA                                   NA
# 103 NA                                   NA
# 104 medical record                       NA
# 105 NA                                   NA
# 106 distal pancreatectomy                whipple
# 107 7                                    7
# 108 yes                                  yes
# 109 NA                                   NA
# 110 NA                                   NA
# 111 no                                   no
# 112 yes                                  yes
# 113 2j                                   2j
# 114 NA                                   NA
# 115 NA                                   NA
# 116 NA                                   NA
# 117 pancreas                             pancreas
# 118 primary                              primary
# 119 false                                false
# 120 2016                                 2016
# 121 2014                                 2014
# 122 2012                                 2012
# 123 NA                                   NA
#     aab9                                 aaba
# 1   Primary solid Tumor                  Primary solid Tumor
# 2   4                                    3
# 3   tcga-2j-aab9                         tcga-2j-aaba
# 4   a5748656-5330-417a-8938-01f69ddb3576 e3a19e63-bae5-498b-9687-41194aa5728d
# 5   dead                                 dead
# 6   627                                  607
# 7   NA                                   NA
# 8   NA                                   NA
# 9   yes                                  yes
# 10  70                                   55
# 11  yes                                  no
# 12  weekly drinker                       NA
# 13  1                                    NA
# 14  head of pancreas                     head of pancreas
# 15  NA                                   NA
# 16  NA                                   NA
# 17  nationwide children's hospital       nationwide children's hospital
# 18  be56b07b-cd57-46a0-baa1-e20169d88468 4dddd9de-1aed-43bd-853e-f1d0a845680e
# 19  NA                                   NA
# 20  NA                                   NA
# 21  NA                                   NA
# 22  NA                                   tcga-2j-aaba-f62440
# 23  NA                                   bcf34d68-2b8f-4de0-8349-435850881a98
# 24  canonical                            canonical
# 25  NA                                   NA
# 26  NA                                   NA
# 27  NA                                   NA
# 28  NA                                   NA
# 29  NA                                   NA
# 30  21                                   21
# ... ...                                  ...
# 94  yes                                  no
# 95  NA                                   NA
# 96  NA                                   NA
# 97  NA                                   NA
# 98  other                                NA
# 99  pancreas                             NA
# 100 r0                                   r1
# 101 NA                                   NA
# 102 NA                                   NA
# 103 NA                                   NA
# 104 medical record                       medical record
# 105 NA                                   NA
# 106 whipple                              whipple
# 107 7                                    7
# 108 yes                                  yes
# 109 NA                                   NA
# 110 NA                                   NA
# 111 no                                   no
# 112 yes                                  yes
# 113 2j                                   2j
# 114 1                                    5
# 115 NA                                   NA
# 116 NA                                   NA
# 117 pancreas                             pancreas
# 118 primary                              primary
# 119 false                                false
# 120 2016                                 2016
# 121 2014                                 2014
# 122 2012                                 2012
# 123 NA                                   NA
#     aabe                                 aabf
# 1   Primary solid Tumor                  Primary solid Tumor
# 2   3                                    2
# 3   tcga-2j-aabe                         tcga-2j-aabf
# 4   58c1c391-5ea3-4432-bb1e-e7e1974954bc 886d6116-d496-444f-9b7b-7449dad31055
# 5   alive                                dead
# 6   NA                                   691
# 7   676                                  NA
# 8   NA                                   NA
# 9   yes                                  yes
# 10  73                                   73
# 11  yes                                  yes
# 12  weekly drinker                       weekly drinker
# 13  1                                    1
# 14  body of pancreas                     head of pancreas
# 15  NA                                   NA
# 16  NA                                   NA
# 17  nationwide children's hospital       nationwide children's hospital
# 18  be93c69f-5cc3-4289-9cb3-79024701026f d4beb2ee-42e9-417d-9ba6-5b9b16c02bae
# 19  NA                                   NA
# 20  NA                                   NA
# 21  NA                                   NA
# 22  tcga-2j-aabe-f62445                  tcga-2j-aabf-f62441
# 23  39f79087-3bcb-492f-8e5a-dc1e909ad01e 79ee881d-e413-43fb-b466-a3dc79ce35aa
# 24  canonical                            canonical
# 25  NA                                   NA
# 26  NA                                   NA
# 27  NA                                   NA
# 28  NA                                   NA
# 29  NA                                   NA
# 30  21                                   21
# ... ...                                  ...
# 94  yes                                  yes
# 95  NA                                   NA
# 96  NA                                   NA
# 97  NA                                   NA
# 98  NA                                   NA
# 99  NA                                   other
# 100 r0                                   r1
# 101 NA                                   NA
# 102 NA                                   NA
# 103 NA                                   NA
# 104 NA                                   medical record
# 105 1970                                 1965
# 106 distal pancreatectomy                whipple
# 107 7                                    7
# 108 yes                                  yes
# 109 NA                                   NA
# 110 NA                                   NA
# 111 no                                   no
# 112 yes                                  yes
# 113 2j                                   2j
# 114 3                                    3
# 115 NA                                   NA
# 116 NA                                   NA
# 117 pancreas                             pancreas
# 118 primary                              primary
# 119 false                                false
# 120 2016                                 2016
# 121 2014                                 2014
# 122 2012                                 2012
# 123 1960                                 1960
#     aabh                                 ...
# 1   Primary solid Tumor                  ...
# 2   2                                    ...
# 3   tcga-2j-aabh                         ...
# 4   c53328b4-0930-4e6a-a648-283b5565295e ...
# 5   alive                                ...
# 6   NA                                   ...
# 7   1287                                 ...
# 8   NA                                   ...
# 9   yes                                  ...
# 10  61                                   ...
# 11  no                                   ...
# 12  NA                                   ...
# 13  NA                                   ...
# 14  body of pancreas                     ...
# 15  NA                                   ...
# 16  NA                                   ...
# 17  nationwide children's hospital       ...
# 18  bd0474cb-d20c-4c4f-bb01-136e2c8fea82 ...
# 19  NA                                   ...
# 20  NA                                   ...
# 21  NA                                   ...
# 22  tcga-2j-aabh-f64915                  ...
# 23  8e321103-3052-40c7-993a-b66f3f4df168 ...
# 24  canonical                            ...
# 25  NA                                   ...
# 26  NA                                   ...
# 27  NA                                   ...
# 28  NA                                   ...
# 29  NA                                   ...
# 30  21                                   ...
# ... ...
# 94  no                                   ...
# 95  NA                                   ...
# 96  NA                                   ...
# 97  NA                                   ...
# 98  NA                                   ...
# 99  other                                ...
# 100 r0                                   ...
# 101 NA                                   ...
# 102 NA                                   ...
# 103 NA                                   ...
# 104 NA                                   ...
# 105 NA                                   ...
# 106 distal pancreatectomy                ...
# 107 7                                    ...
# 108 yes                                  ...
# 109 NA                                   ...
# 110 NA                                   ...
# 111 no                                   ...
# 112 yes                                  ...
# 113 2j                                   ...
# 114 1                                    ...
# 115 NA                                   ...
# 116 NA                                   ...
# 117 pancreas                             ...
# 118 primary                              ...
# 119 false                                ...
# 120 2016                                 ...
# 121 2014                                 ...
# 122 2011                                 ...
# 123 NA                                   ...
#     aauh                                 aaui
# 1   Primary solid Tumor                  Primary solid Tumor
# 2   2                                    5
# 3   tcga-xd-aauh                         tcga-xd-aaui
# 4   b46b5a4c-59fc-4769-b05a-d15f9aaa753a 9a2db69e-d429-45d4-89ca-a2c4e0cfc116
# 5   alive                                dead
# 6   NA                                   366
# 7   395                                  NA
# 8   NA                                   NA
# 9   yes                                  yes
# 10  57                                   50
# 11  yes                                  yes
# 12  daily drinker                        occasional drinker
# 13  NA                                   NA
# 14  head of pancreas                     head of pancreas
# 15  NA                                   NA
# 16  NA                                   NA
# 17  nationwide children's hospital       nationwide children's hospital
# 18  5b6016d8-9650-4fd1-b106-6205343129b4 e5f200b4-1f48-4472-8550-7b1c92d90075
# 19  NA                                   NA
# 20  NA                                   NA
# 21  NA                                   NA
# 22  tcga-xd-aauh-f69138                  tcga-xd-aaui-f69139
# 23  473a0cc5-1c2d-4a17-9c57-e9a4a9cb31df e8855890-f38c-46fd-9d96-e425a0a03193
# 24  canonical                            canonical
# 25  NA                                   NA
# 26  NA                                   NA
# 27  NA                                   NA
# 28  NA                                   NA
# 29  NA                                   NA
# 30  21                                   21
# ... ...                                  ...
# 94  yes                                  no
# 95  NA                                   NA
# 96  NA                                   NA
# 97  NA                                   NA
# 98  NA                                   NA
# 99  other                                NA
# 100 r2                                   r1
# 101 NA                                   NA
# 102 NA                                   NA
# 103 NA                                   NA
# 104 NA                                   NA
# 105 NA                                   NA
# 106 whipple                              whipple
# 107 7                                    7
# 108 yes                                  yes
# 109 NA                                   NA
# 110 NA                                   NA
# 111 yes                                  yes
# 112 no                                   no
# 113 xd                                   xd
# 114 1                                    2
# 115 NA                                   NA
# 116 NA                                   NA
# 117 pancreas                             pancreas
# 118 primary                              primary
# 119 false                                false
# 120 2016                                 2016
# 121 2015                                 2014
# 122 2013                                 2013
# 123 NA                                   1979
#     aaul                                 a8t3
# 1   Primary solid Tumor                  Primary solid Tumor
# 2   3                                    4
# 3   tcga-xd-aaul                         tcga-xn-a8t3
# 4   597a5a56-244b-4218-a55d-5d08217ea28c dd7bcdd8-1660-4dab-9860-9d136c4cee77
# 5   alive                                alive
# 6   NA                                   NA
# 7   498                                  951
# 8   NA                                   NA
# 9   yes                                  yes
# 10  56                                   67
# 11  yes                                  no
# 12  none                                 NA
# 13  NA                                   NA
# 14  head of pancreas                     head of pancreas
# 15  NA                                   NA
# 16  NA                                   NA
# 17  nationwide children's hospital       nationwide children's hospital
# 18  a9badf93-d810-4a9d-b8c6-f566188bbcfa 4433e74c-2dad-4206-9a25-519336fe88fa
# 19  NA                                   NA
# 20  NA                                   NA
# 21  NA                                   NA
# 22  tcga-xd-aaul-f71305                  tcga-xn-a8t3-f70353
# 23  a732d3da-376d-42eb-80a7-2bd2647295e9 139e8cf8-fa4f-4bea-bb58-f9b2d27e2ef0
# 24  canonical                            canonical
# 25  NA                                   NA
# 26  NA                                   NA
# 27  NA                                   NA
# 28  NA                                   NA
# 29  NA                                   NA
# 30  21                                   21
# ... ...                                  ...
# 94  no                                   yes
# 95  NA                                   NA
# 96  NA                                   NA
# 97  NA                                   NA
# 98  NA                                   NA
# 99  NA                                   NA
# 100 r0                                   r1
# 101 NA                                   NA
# 102 NA                                   NA
# 103 NA                                   NA
# 104 NA                                   NA
# 105 NA                                   1981
# 106 whipple                              whipple
# 107 7                                    7
# 108 yes                                  yes
# 109 NA                                   NA
# 110 NA                                   NA
# 111 yes                                  no
# 112 no                                   yes
# 113 xd                                   xn
# 114 2                                    5
# 115 NA                                   NA
# 116 NA                                   NA
# 117 pancreas                             pancreas
# 118 primary                              primary
# 119 false                                false
# 120 2016                                 2016
# 121 2015                                 2015
# 122 2013                                 2012
# 123 1984                                 NA
#     a8t5                                 a89d
# 1   Primary solid Tumor                  Solid Tissue Normal
# 2   5
# 3   tcga-xn-a8t5                         tcga-yb-a89d
# 4   382b279f-87e1-4dbc-a2ca-c1dfde1cf254 b84b58c7-95b8-4162-8e61-414f8fe422c6
# 5   alive                                alive
# 6   NA                                   NA
# 7   720                                  350
# 8   NA                                   NA
# 9   yes                                  yes
# 10  53                                   59
# 11  no                                   no
# 12  NA                                   NA
# 13  NA                                   NA
# 14  head of pancreas                     head of pancreas
# 15  NA                                   NA
# 16  NA                                   NA
# 17  nationwide children's hospital       nationwide children's hospital
# 18  9b3c88fd-4422-44fd-860e-3d6b3ebfe3d0 12ef6f0f-ca63-4139-a4f1-6ad86fc7db61
# 19  NA                                   case matched methylation control
# 20  NA                                   germline comparison
# 21  NA                                   case matched expression control
# 22  tcga-xn-a8t5-f70355                  tcga-yb-a89d-f67752
# 23  a46e8caf-1e09-484f-9c8e-a532dfba6f2e 928ecaa3-6182-42fd-95f8-ec1ce3195d8b
# 24  canonical                            canonical - plus
# 25  NA                                   NA
# 26  NA                                   NA
# 27  NA                                   NA
# 28  NA                                   NA
# 29  NA                                   NA
# 30  21                                   21
# ... ...                                  ...
# 94  yes                                  yes
# 95  NA                                   NA
# 96  NA                                   NA
# 97  NA                                   NA
# 98  NA                                   NA
# 99  NA                                   other
# 100 r1                                   r0
# 101 NA                                   NA
# 102 NA                                   NA
# 103 NA                                   NA
# 104 NA                                   NA
# 105 NA                                   NA
# 106 whipple                              whipple
# 107 7                                    7
# 108 yes                                  yes
# 109 NA                                   NA
# 110 NA                                   NA
# 111 no                                   yes
# 112 yes                                  no
# 113 xn                                   yb
# 114 2                                    1
# 115 NA                                   NA
# 116 NA                                   NA
# 117 pancreas                             pancreas
# 118 primary                              primary
# 119 false                                false
# 120 2016                                 2016
# 121 2015                                 2014
# 122 2012                                 2013
# 123 1974                                 NA
#     a89d.1                               a8sy
# 1   Primary solid Tumor                  Primary solid Tumor
# 2   2                                    3
# 3   tcga-yb-a89d                         tcga-yh-a8sy
# 4   b84b58c7-95b8-4162-8e61-414f8fe422c6 503d7e36-df78-428d-9971-09ff707645c2
# 5   alive                                alive
# 6   NA                                   NA
# 7   350                                  388
# 8   NA                                   NA
# 9   yes                                  yes
# 10  59                                   73
# 11  no                                   yes
# 12  NA                                   weekly drinker
# 13  NA                                   NA
# 14  head of pancreas                     head of pancreas
# 15  NA                                   NA
# 16  NA                                   NA
# 17  nationwide children's hospital       nationwide children's hospital
# 18  12ef6f0f-ca63-4139-a4f1-6ad86fc7db61 50e76899-a6c1-4e0f-943c-025352a012ec
# 19  case matched methylation control     NA
# 20  germline comparison                  NA
# 21  case matched expression control      NA
# 22  tcga-yb-a89d-f67752                  NA
# 23  928ecaa3-6182-42fd-95f8-ec1ce3195d8b NA
# 24  canonical - plus                     canonical
# 25  NA                                   NA
# 26  NA                                   NA
# 27  NA                                   NA
# 28  NA                                   NA
# 29  NA                                   NA
# 30  21                                   21
# ... ...                                  ...
# 94  yes                                  yes
# 95  NA                                   NA
# 96  NA                                   NA
# 97  NA                                   NA
# 98  NA                                   NA
# 99  other                                NA
# 100 r0                                   NA
# 101 NA                                   NA
# 102 NA                                   NA
# 103 NA                                   NA
# 104 NA                                   NA
# 105 NA                                   NA
# 106 whipple                              whipple
# 107 7                                    7
# 108 yes                                  yes
# 109 NA                                   NA
# 110 NA                                   NA
# 111 yes                                  no
# 112 no                                   yes
# 113 yb                                   yh
# 114 1                                    1
# 115 NA                                   NA
# 116 NA                                   NA
# 117 pancreas                             pancreas
# 118 primary                              primary
# 119 false                                false
# 120 2016                                 2016
# 121 2014                                 2014
# 122 2013                                 2011
# 123 NA                                   NA
#     a8lh                                 aapl
# 1   Primary solid Tumor                  Primary solid Tumor
# 2   1                                    5
# 3   tcga-yy-a8lh                         tcga-z5-aapl
# 4   ede2e8a7-465e-4725-880d-519899aba0c0 6a4e10b6-e6c4-4210-ae4d-0d8e8d0cb3ec
# 5   alive                                alive
# 6   NA                                   NA
# 7   2016                                 467
# 8   NA                                   NA
# 9   yes                                  yes
# 10  61                                   74
# 11  yes                                  NA
# 12  occasional drinker                   NA
# 13  NA                                   NA
# 14  tail of pancreas                     other (please specify)
# 15  NA                                   body and tail
# 16  NA                                   NA
# 17  nationwide children's hospital       nationwide children's hospital
# 18  893dfe82-0fcb-49c5-8d0e-04b112d524f2 4304b319-7904-42bb-b278-e5638edbe1a1
# 19  NA                                   NA
# 20  NA                                   NA
# 21  NA                                   NA
# 22  tcga-yy-a8lh-f66996                  tcga-z5-aapl-f69054
# 23  924c1390-003e-4190-8e65-f5c9faa23610 6e0e4e05-e90c-469b-8039-630009f29f41
# 24  canonical                            canonical
# 25  NA                                   NA
# 26  NA                                   NA
# 27  NA                                   NA
# 28  NA                                   NA
# 29  NA                                   NA
# 30  21                                   21
# ... ...                                  ...
# 94  yes                                  no
# 95  NA                                   NA
# 96  NA                                   NA
# 97  NA                                   NA
# 98  other                                NA
# 99  breast                               NA
# 100 r0                                   r0
# 101 NA                                   NA
# 102 NA                                   NA
# 103 NA                                   NA
# 104 NA                                   NA
# 105 NA                                   NA
# 106 other method (please specify)        NA
# 107 6                                    7
# 108 yes                                  yes
# 109 NA                                   NA
# 110 NA                                   NA
# 111 no                                   yes
# 112 yes                                  no
# 113 yy                                   z5
# 114 2                                    1
# 115 NA                                   NA
# 116 NA                                   NA
# 117 pancreas                             pancreas
# 118 primary                              primary
# 119 false                                false
# 120 2016                                 2016
# 121 2014                                 2014
# 122 2009                                 2013
# 123 1963                                 NA

# %% [markdown]
# ### Transpose the data sets

# %%
transposefunction <- function(dataset){
    rowname <- dataset$participant_id
    colname <- 1:length(original_dataset[1,])
    transposed_dataset <- transpose(dataset)
    rownames(transposed_dataset) <- colname
    colnames(transposed_dataset) <- rowname
    transposed_dataset <- transposed_dataset[2:nrow(transposed_dataset),]
    return(transposed_dataset)
}

t_expression_data <- transposefunction(Expression_data)
t_patient_data <- transposefunction(Patient_data)

dim(t_expression_data)
dim(t_patient_data)
# Out:
# [1]   183 18465
# [1] 183 123

# %%
sum(is.na(t_expression_data))
summary(is.na(t_expression_data))
## there are no missing values in the expression data set
# Out:
# [1] 0
#   SLC35E2           A1BG            A1CF           A2BP1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    A2LD1           A2ML1            A2M            A4GALT
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    A4GNT            AAA1            AAAS           AACSL
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     AACS           AADAC           AADAT           AAGAB
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     AAK1            AAMP           AANAT           AARS2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AARSD1           AARS          AASDHPPT         AASDH
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     AASS            AATF            AATK            ABAT
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ABCA10         ABCA11P          ABCA12          ABCA13
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ABCA17P          ABCA1           ABCA2           ABCA3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ABCA4           ABCA5           ABCA6           ABCA7
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ABCA8           ABCA9           ABCB10          ABCB11
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ABCB1           ABCB4           ABCB5           ABCB6
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ABCB7           ABCB8           ABCB9           ABCC10
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ABCC11          ABCC13          ABCC1           ABCC2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ABCC3           ABCC4           ABCC5          ABCC6P1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ABCC6P2          ABCC6           ABCC8           ABCC9
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ABCD1           ABCD2           ABCD3           ABCD4
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ABCE1           ABCF1           ABCF2           ABCF3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ABCG1           ABCG2           ABCG4           ABCG5
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ABCG8           ABHD10          ABHD11         ABHD12B
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ABHD12          ABHD13         ABHD14A         ABHD14B
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ABHD15          ABHD1           ABHD2           ABHD3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ABHD4           ABHD5           ABHD6           ABHD8
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ABI1            ABI2           ABI3BP           ABI3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ABL1            ABL2           ABLIM1          ABLIM2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ABLIM3           ABO             ABP1            ABRA
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ABR             ABT1           ABTB1           ABTB2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACAA1           ACAA2           ACACA           ACACB
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACAD10          ACAD11          ACAD8           ACAD9
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACADL           ACADM           ACADSB          ACADS
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACADVL           ACAN           ACAP1           ACAP2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACAP3           ACAT1           ACAT2           ACBD3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACBD4           ACBD5           ACBD6           ACBD7
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACCN1           ACCN2           ACCN3           ACCN4
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ACCS            ACD             ACE2           ACER1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACER2           ACER3            ACE             ACHE
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACIN1            ACLY           ACMSD            ACN9
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ACO1            ACO2           ACOT11          ACOT13
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACOT1           ACOT2           ACOT4           ACOT6
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACOT7           ACOT8           ACOT9           ACOX1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACOX2           ACOX3           ACOXL            ACP1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ACP2            ACP5            ACP6           ACPL2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ACPP           ACRBP            ACRC           ACRV1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ACR            ACSBG1          ACSBG2          ACSF2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACSF3           ACSL1           ACSL3           ACSL4
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACSL5           ACSL6           ACSM1           ACSM2A
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACSM2B          ACSM3           ACSM5           ACSS1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACSS2           ACSS3           ACTA1           ACTA2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACTBL2           ACTB           ACTC1           ACTG1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACTG2           ACTL6A          ACTL6B          ACTL8
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACTN1           ACTN2           ACTN3           ACTN4
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACTR10          ACTR1A          ACTR1B          ACTR2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACTR3B          ACTR3C          ACTR3           ACTR5
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACTR6           ACTR8           ACVR1B          ACVR1C
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ACVR1           ACVR2A          ACVR2B          ACVRL1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ACY1            ACY3           ACYP1           ACYP2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ADAD2            ADAL           ADAM10          ADAM11
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ADAM12          ADAM15          ADAM17          ADAM19
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ADAM20         ADAM21P1         ADAM21          ADAM22
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ADAM23          ADAM28          ADAM29          ADAM32
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ADAM33          ADAM6           ADAM8           ADAM9
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ADAMDEC1        ADAMTS10        ADAMTS12        ADAMTS13
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ADAMTS14        ADAMTS15        ADAMTS16        ADAMTS17
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ADAMTS18        ADAMTS19        ADAMTS1         ADAMTS2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ADAMTS3         ADAMTS4         ADAMTS5         ADAMTS6
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ADAMTS7         ADAMTS8         ADAMTS9         ADAMTSL1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ADAMTSL2        ADAMTSL3        ADAMTSL4        ADAMTSL5
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ADAP1           ADAP2           ADARB1          ADARB2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ADAR           ADAT1           ADAT2           ADAT3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ADA            ADCK1           ADCK2           ADCK4
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ADCK5           ADCY10          ADCY1           ADCY2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ADCY3           ADCY4           ADCY5           ADCY6
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ADCY7           ADCY8           ADCY9         ADCYAP1R1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ADCYAP1           ADC             ADD1            ADD2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ADD3           ADH1A           ADH1B           ADH1C
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ADH4            ADH5            ADH6           ADHFE1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ADI1           ADIPOQ         ADIPOR1         ADIPOR2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ADK             ADM2            ADM            ADNP2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ADNP           ADORA1         ADORA2A         ADORA2B
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ADORA3           ADO            ADPGK          ADPRHL1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ADPRHL2          ADPRH           ADRA1A          ADRA1B
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ADRA1D          ADRA2A          ADRA2B          ADRA2C
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ADRB1           ADRB2           ADRB3           ADRBK1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ADRBK2          ADRM1            ADSL           ADSSL1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ADSS           AEBP1           AEBP2            AEN
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     AES           AFAP1L1         AFAP1L2          AFAP1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AFARP1           AFF1            AFF2            AFF3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     AFF4           AFG3L1          AFG3L2          AFMID
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     AFM             AFP            AFTPH            AG2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AGAP11          AGAP1           AGAP2           AGAP3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AGAP4           AGAP5           AGAP6           AGAP7
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AGAP8            AGA            AGBL2           AGBL3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AGBL4           AGBL5            AGER           AGFG1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AGFG2           AGGF1            AGK             AGL
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AGMAT           AGPAT1          AGPAT2          AGPAT3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AGPAT4          AGPAT5          AGPAT6          AGPAT9
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AGPHD1           AGPS            AGR2            AGR3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     AGRN            AGRP          AGTPBP1          AGTR1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AGTR2           AGTRAP           AGT           AGXT2L1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   AGXT2L2           AGXT           AHCTF1          AHCYL1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AHCYL2           AHCY           AHDC1            AHI1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AHNAK2          AHNAK            AHRR            AHR
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AHSA1           AHSA2            AHSG            AHSP
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AICDA            AIDA           AIF1L            AIF1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AIFM1           AIFM2           AIFM3            AIG1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AIM1L            AIM1            AIM2           AIMP1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AIMP2           AIPL1            AIP             AIRE
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AJAP1            AK1             AK2            AK3L1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     AK3             AK5             AK7            AKAP10
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AKAP11          AKAP12          AKAP13          AKAP14
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AKAP1           AKAP2           AKAP3           AKAP4
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AKAP5           AKAP6           AKAP7           AKAP8L
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AKAP8           AKAP9            AKD1          AKIRIN1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   AKIRIN2          AKNAD1           AKNA           AKR1A1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   AKR1B10         AKR1B15          AKR1B1          AKR1C1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AKR1C2          AKR1C3          AKR1C4          AKR1D1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AKR1E2          AKR7A2          AKR7A3          AKR7L
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AKT1S1           AKT1            AKT2            AKT3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AKTIP            ALAD           ALAS1           ALAS2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ALB            ALCAM          ALDH16A1        ALDH18A1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ALDH1A1         ALDH1A2         ALDH1A3         ALDH1B1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ALDH1L1         ALDH1L2          ALDH2          ALDH3A1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ALDH3A2         ALDH3B1         ALDH3B2         ALDH4A1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ALDH5A1         ALDH6A1         ALDH7A1         ALDH8A1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ALDH9A1          ALDOA           ALDOB           ALDOC
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ALG10B          ALG10           ALG11           ALG12
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ALG13           ALG14           ALG1L2          ALG1L
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ALG1            ALG2            ALG3            ALG5
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ALG6            ALG8            ALG9           ALKBH1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ALKBH2          ALKBH3          ALKBH4          ALKBH5
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ALKBH6          ALKBH7          ALKBH8           ALK
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ALLC           ALMS1P          ALMS1          ALOX12B
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ALOX12P2         ALOX12         ALOX15B          ALOX15
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ALOX5AP          ALOX5           ALOXE3           ALPI
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ALPK1           ALPK2           ALPK3            ALPL
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ALPPL2           ALPP           ALS2CL         ALS2CR11
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ALS2CR12        ALS2CR4         ALS2CR8           ALS2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ALX1            ALX3          AMAC1L2         AMAC1L3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AMACR            AMBP           AMBRA1           AMD1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AMDHD1          AMDHD2           AMFR           AMHR2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     AMH            AMICA1          AMIGO1          AMIGO2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AMIGO3         AMMECR1L        AMMECR1           AMN1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     AMN            AMOTL1          AMOTL2           AMOT
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AMPD1           AMPD2           AMPD3            AMPH
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     AMTN            AMT            AMY1A           AMY2A
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AMY2B            AMZ1           AMZ2P1           AMZ2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ANAPC10         ANAPC11         ANAPC13         ANAPC16
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ANAPC1          ANAPC2          ANAPC4          ANAPC5
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ANAPC7          ANGEL1          ANGEL2          ANGPT1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ANGPT2          ANGPT4         ANGPTL1         ANGPTL2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ANGPTL3         ANGPTL4         ANGPTL5         ANGPTL6
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ANGPTL7           ANG             ANK1            ANK2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ANK3           ANKAR          ANKDD1A          ANKFN1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ANKFY1        ANKHD1-EIF4EBP3   ANKHD1           ANKH
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ANKIB1          ANKK1           ANKLE1          ANKLE2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ANKMY1          ANKMY2          ANKRA2         ANKRD10
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ANKRD11         ANKRD12         ANKRD13A        ANKRD13B
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ANKRD13C        ANKRD13D        ANKRD16         ANKRD17
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ANKRD19          ANKRD1        ANKRD20A3       ANKRD20A4
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ANKRD20B        ANKRD22         ANKRD23         ANKRD24
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#  ANKRD26P1        ANKRD26         ANKRD27         ANKRD28
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ANKRD29          ANKRD2         ANKRD30B        ANKRD31
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ANKRD32         ANKRD33         ANKRD34A        ANKRD34B
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ANKRD34C        ANKRD35        ANKRD36BP1       ANKRD36B
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ANKRD36         ANKRD37         ANKRD39         ANKRD40
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ANKRD42         ANKRD43         ANKRD44         ANKRD45
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ANKRD46         ANKRD49         ANKRD50         ANKRD52
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ANKRD53         ANKRD54         ANKRD55         ANKRD56
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ANKRD57         ANKRD58          ANKRD5          ANKRD6
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ANKRD7          ANKRD9          ANKS1A          ANKS1B
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ANKS3           ANKS4B          ANKS6           ANKZF1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ANLN           ANO10            ANO1            ANO2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ANO3            ANO4            ANO5            ANO6
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ANO7            ANO8            ANO9           ANP32A
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ANP32B          ANP32C          ANP32E          ANPEP
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ANTXR1          ANTXR2          ANUBL1          ANXA10
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ANXA11          ANXA13          ANXA1          ANXA2P1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ANXA2P2         ANXA2P3          ANXA2           ANXA3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ANXA4           ANXA5           ANXA6           ANXA7
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ANXA8L2          ANXA8           ANXA9            AOAH
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     AOC2            AOC3            AOX1           AP1AR
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AP1B1           AP1G1           AP1G2           AP1M1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AP1M2           AP1S1           AP1S2           AP1S3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AP2A1           AP2A2           AP2B1           AP2M1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AP2S1           AP3B1           AP3B2           AP3D1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AP3M1           AP3M2           AP3S1           AP3S2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AP4B1           AP4E1           AP4M1           AP4S1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    APAF1           APBA1           APBA2           APBA3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   APBB1IP          APBB1           APBB2           APBB3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     APC2          APCDD1L          APCDD1           APCS
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     APC             APEH           APEX1           APEX2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    APH1A           APH1B            API5            APIP
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    APITD1           APLF           APLNR            APLN
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    APLP1           APLP2          APOA1BP          APOA1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    APOA4           APOA5          APOB48R         APOBEC1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   APOBEC2         APOBEC3A        APOBEC3B        APOBEC3C
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   APOBEC3D        APOBEC3F        APOBEC3G        APOBEC3H
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   APOBEC4           APOB          APOC1P1          APOC1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    APOC2           APOC3           APOC4            APOD
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     APOE            APOF            APOH           APOL1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    APOL2           APOL3           APOL4           APOL6
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    APOLD1           APOM           APOOL            APOO
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    APPBP2          APPL1           APPL2            APP
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     APRT            APTX           AQP10           AQP11
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AQP12A          AQP12B           AQP1            AQP2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     AQP3            AQP4            AQP5            AQP6
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    AQP7P1          AQP7P3           AQP7            AQP8
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     AQP9           AQPEP            AQR             ARAF
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ARAP1           ARAP2           ARAP3           ARCN1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ARC             AREG            ARF1            ARF3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ARF4            ARF5            ARF6          ARFGAP1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ARFGAP2         ARFGAP3         ARFGEF1         ARFGEF2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ARFIP1          ARFIP2          ARFRP1           ARG1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ARG2          ARGFXP2          ARGLU1         ARHGAP10
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#  ARHGAP11A       ARHGAP11B        ARHGAP12        ARHGAP15
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ARHGAP17        ARHGAP18        ARHGAP19        ARHGAP1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ARHGAP20        ARHGAP21        ARHGAP22        ARHGAP23
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ARHGAP24        ARHGAP25        ARHGAP26        ARHGAP27
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ARHGAP28        ARHGAP29        ARHGAP30        ARHGAP31
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ARHGAP32        ARHGAP33        ARHGAP36        ARHGAP39
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ARHGAP42        ARHGAP4         ARHGAP5         ARHGAP6
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ARHGAP8         ARHGAP9         ARHGDIA         ARHGDIB
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ARHGDIG        ARHGEF10L        ARHGEF10        ARHGEF11
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ARHGEF12        ARHGEF15        ARHGEF16        ARHGEF17
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ARHGEF18        ARHGEF19        ARHGEF1         ARHGEF2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ARHGEF33        ARHGEF35        ARHGEF37        ARHGEF38
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ARHGEF3         ARHGEF4         ARHGEF5         ARHGEF6
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ARHGEF7         ARHGEF9          ARID1A          ARID1B
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ARID2           ARID3A          ARID3B          ARID3C
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ARID4A          ARID4B          ARID5A          ARID5B
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ARIH1           ARIH2           ARL10           ARL11
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ARL13A          ARL13B          ARL14           ARL15
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ARL16           ARL17A          ARL17B           ARL1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ARL2BP           ARL2            ARL3           ARL4A
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ARL4C           ARL4D           ARL5A           ARL5B
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ARL5C          ARL6IP1         ARL6IP4         ARL6IP5
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ARL6IP6           ARL6           ARL8A           ARL8B
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ARL9           ARMC10          ARMC1           ARMC2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ARMC3           ARMC4           ARMC5           ARMC6
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ARMC7           ARMC8           ARMC9           ARMCX1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ARMCX2          ARMCX3          ARMCX5          ARMCX6
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ARMS2           ARNT2           ARNTL2          ARNTL
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ARNT           ARPC1A          ARPC1B          ARPC2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ARPC3           ARPC4           ARPC5L          ARPC5
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ARPM1           ARPP19          ARPP21          ARRB1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ARRB2           ARRDC1          ARRDC2          ARRDC3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
# ...
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF490          ZNF491          ZNF492          ZNF493
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF496          ZNF497          ZNF498          ZNF500
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF501          ZNF502          ZNF503          ZNF506
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF507          ZNF510          ZNF511         ZNF512B
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF512          ZNF513          ZNF514          ZNF516
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF517         ZNF518A         ZNF518B          ZNF519
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF521          ZNF524          ZNF525          ZNF526
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF527          ZNF528          ZNF529          ZNF530
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF532          ZNF534          ZNF536          ZNF540
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF541          ZNF542          ZNF543          ZNF544
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF546          ZNF547          ZNF548          ZNF549
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF550          ZNF551          ZNF552          ZNF554
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF555          ZNF556          ZNF557          ZNF558
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF559          ZNF560          ZNF561          ZNF562
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF563          ZNF564          ZNF565          ZNF566
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF567          ZNF568          ZNF569          ZNF570
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF571          ZNF572          ZNF573          ZNF574
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF575          ZNF576          ZNF577          ZNF578
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF579          ZNF57           ZNF580          ZNF581
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF582          ZNF583          ZNF584         ZNF585A
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ZNF585B          ZNF586          ZNF587          ZNF589
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF592          ZNF593          ZNF594          ZNF595
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF596          ZNF597          ZNF598          ZNF599
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF600          ZNF605          ZNF606          ZNF607
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF608          ZNF609          ZNF610          ZNF611
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF613          ZNF614          ZNF615          ZNF616
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF618          ZNF619          ZNF620          ZNF621
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF622          ZNF623          ZNF624          ZNF625
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF626          ZNF627          ZNF628          ZNF629
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF630          ZNF638          ZNF639          ZNF641
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF642          ZNF643          ZNF644          ZNF646
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF648          ZNF649          ZNF652          ZNF653
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF654          ZNF655          ZNF658          ZNF660
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF662          ZNF664          ZNF665          ZNF667
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF668          ZNF669          ZNF670          ZNF671
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF672          ZNF673          ZNF674          ZNF675
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF676          ZNF677          ZNF678          ZNF680
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF681          ZNF682          ZNF683          ZNF684
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF687          ZNF688          ZNF689          ZNF691
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF692          ZNF695          ZNF696          ZNF697
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF699          ZNF69           ZNF700          ZNF701
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ZNF702P          ZNF703          ZNF704         ZNF705A
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF706          ZNF707          ZNF708          ZNF709
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF70           ZNF710          ZNF711          ZNF713
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF714          ZNF717          ZNF718          ZNF71
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF720          ZNF721          ZNF727          ZNF732
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF737          ZNF738          ZNF740          ZNF746
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF747          ZNF749          ZNF74           ZNF750
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF75A          ZNF75D          ZNF761          ZNF763
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF764          ZNF765          ZNF766          ZNF767
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF768          ZNF76           ZNF770          ZNF771
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF772          ZNF773          ZNF774          ZNF775
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF776          ZNF777          ZNF778          ZNF77
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ZNF780A         ZNF780B          ZNF781          ZNF782
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF784          ZNF785          ZNF786          ZNF787
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF788          ZNF789          ZNF790          ZNF791
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF792          ZNF793          ZNF799          ZNF79
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ZNF7           ZNF800         ZNF804A          ZNF805
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF808          ZNF80           ZNF813          ZNF814
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF815         ZNF816A          ZNF81           ZNF821
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF823          ZNF826          ZNF827          ZNF828
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF829          ZNF830          ZNF831          ZNF833
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF835          ZNF836          ZNF837          ZNF839
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF83           ZNF841          ZNF843          ZNF844
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF845          ZNF846          ZNF84           ZNF853
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF85           ZNF860          ZNF862         ZNF876P
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF878          ZNF879          ZNF880          ZNF883
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ZNF8           ZNF90           ZNF91           ZNF92
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNF93           ZNF98           ZNF99           ZNFX1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNHIT1          ZNHIT2          ZNHIT3          ZNHIT6
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZNRD1           ZNRF1           ZNRF2           ZNRF3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ZP1             ZP3            ZPBP2           ZPLD1
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZRANB1          ZRANB2          ZRANB3          ZRSR2
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#  ZSCAN12P1        ZSCAN12         ZSCAN16         ZSCAN18
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZSCAN1         ZSCAN20         ZSCAN21         ZSCAN22
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ZSCAN23         ZSCAN29          ZSCAN2          ZSCAN4
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#   ZSCAN5A         ZSCAN5B          ZSWIM1          ZSWIM3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZSWIM4          ZSWIM5          ZSWIM6          ZSWIM7
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZUFSP            ZW10           ZWILCH          ZWINT
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#     ZXDA            ZXDB            ZXDC           ZYG11A
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#    ZYG11B           ZYX            ZZEF1            ZZZ3
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:184       FALSE:184       FALSE:184       FALSE:184
#  psiTPTE22
#  Mode :logical
#  FALSE:184

# %%
sum(is.na(t_patient_data))

dimensions <- dim(t_patient_data)
dimensions[1]*dimensions[2]

summary(is.na(t_patient_data))
## 9654 of 22632 are missing values --> but some have a meaning (e.g. when patients haven't died days_to_death is NA)
# Out:
# [1] 9654
# [1] 22632
#  sample_type     mRNAseq_cluster bcr_patient_barcode bcr_patient_uuid
#  Mode :logical   Mode :logical   Mode :logical       Mode :logical
#  FALSE:184       FALSE:184       FALSE:184           FALSE:184
#
#  vital_status    days_to_death   days_to_last_followup additional_studies
#  Mode :logical   Mode :logical   Mode :logical         Mode :logical
#  FALSE:184       FALSE:96        FALSE:89              FALSE:1
#                  TRUE :88        TRUE :95              TRUE :183
#  adenocarcinoma_invasion age_at_initial_pathologic_diagnosis
#  Mode :logical           Mode :logical
#  FALSE:184               FALSE:184
#
#  alcohol_history_documented alcoholic_exposure_category
#  Mode :logical              Mode :logical
#  FALSE:172                  FALSE:103
#  TRUE :12                   TRUE :81
#  amount_of_alcohol_consumption_per_day anatomic_neoplasm_subdivision
#  Mode :logical                         Mode :logical
#  FALSE:33                              FALSE:184
#  TRUE :151
#  anatomic_neoplasm_subdivision_other b_symptoms         bcr
#  Mode :logical                       Mode :logical   Mode :logical
#  FALSE:12                            FALSE:1         FALSE:184
#  TRUE :172                           TRUE :183
#  bcr_aliquot_uuid bcr_canonical_reason-2 bcr_canonical_reason-3
#  Mode :logical    Mode :logical          Mode :logical
#  FALSE:184        FALSE:9                FALSE:9
#                   TRUE :175              TRUE :175
#  bcr_canonical_reason bcr_followup_barcode bcr_followup_uuid
#  Mode :logical        Mode :logical        Mode :logical
#  FALSE:13             FALSE:155            FALSE:155
#  TRUE :171            TRUE :29             TRUE :29
#  bcr_patient_canonical_status clinical_m      clinical_n      clinical_stage
#  Mode :logical                Mode :logical   Mode :logical   Mode :logical
#  FALSE:184                    FALSE:1         FALSE:1         FALSE:1
#                               TRUE :183       TRUE :183       TRUE :183
#  clinical_t      course_number   day_of_dcc_upload day_of_form_completion
#  Mode :logical   Mode :logical   Mode :logical     Mode :logical
#  FALSE:1         FALSE:1         FALSE:184         FALSE:184
#  TRUE :183       TRUE :183
#  days_to_birth   days_to_diabetes_onset days_to_index
#  Mode :logical   Mode :logical          Mode :logical
#  FALSE:184       FALSE:15               FALSE:183
#                  TRUE :169              TRUE :1
#  days_to_initial_pathologic_diagnosis days_to_pancreatitis_onset
#  Mode :logical                        Mode :logical
#  FALSE:183                            FALSE:12
#  TRUE :1                              TRUE :172
#  days_to_psa     disease_code      drugs         ethnicity
#  Mode :logical   Mode :logical   Mode :logical   Mode :logical
#  FALSE:1         FALSE:184       FALSE:1         FALSE:141
#  TRUE :183                       TRUE :183       TRUE :43
#  extranodal_involvement family_history_of_cancer file_uuid
#  Mode :logical          Mode :logical            Mode :logical
#  FALSE:1                FALSE:115                FALSE:184
#  TRUE :183              TRUE :69
#  follow_ups      followup_case_report_form_submission_reason
#  Mode :logical   Mode :logical
#  FALSE:1         FALSE:152
#  TRUE :183       TRUE :32
#  followup_treatment_success frequency_of_alcohol_consumption   gender
#  Mode :logical              Mode :logical                    Mode :logical
#  FALSE:89                   FALSE:34                         FALSE:184
#  TRUE :95                   TRUE :150
#  gleason_score   histologic_grading_tier_category histological_type
#  Mode :logical   Mode :logical                    Mode :logical
#  FALSE:1         FALSE:110                        FALSE:183
#  TRUE :183       TRUE :74                         TRUE :1
#  histological_type_other history_of_chronic_pancreatitis history_of_diabetes
#  Mode :logical           Mode :logical                   Mode :logical
#  FALSE:28                FALSE:147                       FALSE:152
#  TRUE :156               TRUE :37                        TRUE :32
#  history_of_neoadjuvant_treatment history_prior_surgery_type_other
#  Mode :logical                    Mode :logical
#  FALSE:184                        FALSE:14
#                                   TRUE :170
#  hiv_status        icd_10        icd_o_3_histology icd_o_3_site
#  Mode :logical   Mode :logical   Mode :logical     Mode :logical
#  FALSE:1         FALSE:184       FALSE:184         FALSE:184
#  TRUE :183
#  igcccg_stage    informed_consent_verified init_pathology_dx_method_other
#  Mode :logical   Mode :logical             Mode :logical
#  FALSE:1         FALSE:184                 FALSE:6
#  TRUE :183                                 TRUE :178
#  initial_pathologic_diagnosis_method lost_follow_up  lymph_node_examined_count
#  Mode :logical                       Mode :logical   Mode :logical
#  FALSE:179                           FALSE:154       FALSE:180
#  TRUE :5                             TRUE :30        TRUE :4
#  masaoka_stage   maximum_tumor_dimension
#  Mode :logical   Mode :logical
#  FALSE:1         FALSE:170
#  TRUE :183       TRUE :14
#  mononucleotide_and_dinucleotide_marker_panel_analysis_status
#  Mode :logical
#  FALSE:184
#
#  mononucleotide_marker_panel_analysis_status month_of_dcc_upload
#  Mode :logical                               Mode :logical
#  FALSE:1                                     FALSE:184
#  TRUE :183
#  month_of_form_completion neoplasm_histologic_grade number_cycles
#  Mode :logical            Mode :logical             Mode :logical
#  FALSE:184                FALSE:184                 FALSE:1
#                                                     TRUE :183
#  number_of_lymphnodes_positive_by_he number_of_lymphnodes_positive_by_ihc
#  Mode :logical                       Mode :logical
#  FALSE:180                           FALSE:59
#  TRUE :4                             TRUE :125
#  number_pack_years_smoked  other_dx       pathologic_m    pathologic_n
#  Mode :logical            Mode :logical   Mode :logical   Mode :logical
#  FALSE:60                 FALSE:184       FALSE:184       FALSE:183
#  TRUE :124                                                TRUE :1
#  pathologic_stage pathologic_t    patient_death_reason
#  Mode :logical    Mode :logical   Mode :logical
#  FALSE:182        FALSE:183       FALSE:77
#  TRUE :2          TRUE :1         TRUE :107
#  person_neoplasm_cancer_status prescribed_dose prescribed_dose_units
#  Mode :logical                 Mode :logical   Mode :logical
#  FALSE:164                     FALSE:1         FALSE:1
#  TRUE :20                      TRUE :183       TRUE :183
#  primary_lymph_node_presentation_assessment primary_pattern
#  Mode :logical                              Mode :logical
#  FALSE:183                                  FALSE:1
#  TRUE :1                                    TRUE :183
#  primary_therapy_outcome_success progression_determined_by-3 project_code
#  Mode :logical                   Mode :logical               Mode :logical
#  FALSE:146                       FALSE:2                     FALSE:184
#  TRUE :38                        TRUE :182
#  psa_value          race         radiation_therapy radiation_type_notes
#  Mode :logical   Mode :logical   Mode :logical     Mode :logical
#  FALSE:1         FALSE:180       FALSE:169         FALSE:1
#  TRUE :183       TRUE :4         TRUE :15          TRUE :183
#  radiations      regimen_number  relative_cancer_type-2 relative_cancer_type
#  Mode :logical   Mode :logical   Mode :logical          Mode :logical
#  FALSE:1         FALSE:1         FALSE:9                FALSE:66
#  TRUE :183       TRUE :183       TRUE :175              TRUE :118
#  residual_tumor  route_of_administration secondary_pattern serum_markers
#  Mode :logical   Mode :logical           Mode :logical     Mode :logical
#  FALSE:172       FALSE:1                 FALSE:1           FALSE:1
#  TRUE :12        TRUE :183               TRUE :183         TRUE :183
#  source_of_patient_death_reason stopped_smoking_year surgery_performed_type
#  Mode :logical                  Mode :logical        Mode :logical
#  FALSE:58                       FALSE:53             FALSE:182
#  TRUE :126                      TRUE :131            TRUE :2
#  system_version  targeted_molecular_therapy tertiary_pattern therapy_type_notes
#  Mode :logical   Mode :logical              Mode :logical    Mode :logical
#  FALSE:184       FALSE:173                  FALSE:1          FALSE:1
#                  TRUE :11                   TRUE :183        TRUE :183
#  tissue_prospective_collection_indicator
#  Mode :logical
#  FALSE:184
#
#  tissue_retrospective_collection_indicator tissue_source_site
#  Mode :logical                             Mode :logical
#  FALSE:184                                 FALSE:184
#
#  tobacco_smoking_history total_dose      total_dose_units tumor_tissue_site
#  Mode :logical           Mode :logical   Mode :logical    Mode :logical
#  FALSE:149               FALSE:1         FALSE:1          FALSE:184
#  TRUE :35                TRUE :183       TRUE :183
#  tumor_type      withdrawn       year_of_dcc_upload year_of_form_completion
#  Mode :logical   Mode :logical   Mode :logical      Mode :logical
#  FALSE:184       FALSE:184       FALSE:184          FALSE:184
#
#  year_of_initial_pathologic_diagnosis year_of_tobacco_smoking_onset
#  Mode :logical                        Mode :logical
#  FALSE:183                            FALSE:49
#  TRUE :1                              TRUE :135

# %%
head(t_patient_data,20)
# Out:
#    sample_type         mRNAseq_cluster bcr_patient_barcode
# 1  sample_type         mRNAseq_cluster bcr_patient_barcode
# 2  Primary solid Tumor 1               tcga-2j-aab1
# 3  Primary solid Tumor 2               tcga-2j-aab4
# 4  Primary solid Tumor 3               tcga-2j-aab6
# 5  Primary solid Tumor 1               tcga-2j-aab8
# 6  Primary solid Tumor 4               tcga-2j-aab9
# 7  Primary solid Tumor 3               tcga-2j-aaba
# 8  Primary solid Tumor 3               tcga-2j-aabe
# 9  Primary solid Tumor 2               tcga-2j-aabf
# 10 Primary solid Tumor 2               tcga-2j-aabh
# 11 Primary solid Tumor 3               tcga-2j-aabi
# 12 Primary solid Tumor 2               tcga-2j-aabk
# 13 Primary solid Tumor 3               tcga-2j-aabo
# 14 Primary solid Tumor 5               tcga-2j-aabp
# 15 Primary solid Tumor 4               tcga-2j-aabr
# 16 Primary solid Tumor 5               tcga-2j-aabt
# 17 Primary solid Tumor 3               tcga-2j-aabu
# 18 Primary solid Tumor 4               tcga-2j-aabv
# 19 Primary solid Tumor 1               tcga-2l-aaqa
# 20 Primary solid Tumor 3               tcga-2l-aaqe
#    bcr_patient_uuid                     vital_status days_to_death
# 1  bcr_patient_uuid                     vital_status days_to_death
# 2  75119d1a-93e5-4ae7-9d60-69ee929a0772 dead         66
# 3  33833131-1482-42d5-9cf5-01cade540234 alive        NA
# 4  70797499-16e6-48cc-8ae4-1e692713dad3 dead         293
# 5  2e8f90f4-aed3-43b0-985c-dfdc2581f24f alive        NA
# 6  a5748656-5330-417a-8938-01f69ddb3576 dead         627
# 7  e3a19e63-bae5-498b-9687-41194aa5728d dead         607
# 8  58c1c391-5ea3-4432-bb1e-e7e1974954bc alive        NA
# 9  886d6116-d496-444f-9b7b-7449dad31055 dead         691
# 10 c53328b4-0930-4e6a-a648-283b5565295e alive        NA
# 11 2aaf212f-000a-4a9d-8a4a-198fa94f491e alive        NA
# 12 c24c54ea-4095-460d-bb53-e3629a56cd62 alive        NA
# 13 a8c3e333-865d-4060-8ce4-453aa6f9f0e8 alive        NA
# 14 a4569ce7-dde7-4660-a24c-409d294b2b8c alive        NA
# 15 507a4e05-d5ab-4dbb-9b4f-76b1a21b79dd alive        NA
# 16 3f9cc59e-9f7d-40d1-9365-28b40dff3c59 alive        NA
# 17 0b4b50c7-aa0b-4a64-807b-d3cb47eeeb6f dead         277
# 18 232073a1-2bf3-4539-a396-bde7836f9aeb dead         652
# 19 d8aa891c-8050-471e-ad3e-32b9c5e9db03 dead         143
# 20 8e7d5615-5142-4d53-a460-2cafade1f690 dead         684
#    days_to_last_followup additional_studies adenocarcinoma_invasion
# 1  days_to_last_followup additional_studies adenocarcinoma_invasion
# 2  NA                    NA                 yes
# 3  729                   NA                 yes
# 4  NA                    NA                 yes
# 5  80                    NA                 yes
# 6  NA                    NA                 yes
# 7  NA                    NA                 yes
# 8  676                   NA                 yes
# 9  NA                    NA                 yes
# 10 1287                  NA                 yes
# 11 969                   NA                 yes
# 12 484                   NA                 yes
# 13 440                   NA                 yes
# 14 463                   NA                 yes
# 15 438                   NA                 yes
# 16 319                   NA                 yes
# 17 NA                    NA                 yes
# 18 NA                    NA                 yes
# 19 NA                    NA                 yes
# 20 NA                    NA                 yes
#    age_at_initial_pathologic_diagnosis ... tobacco_smoking_history total_dose
# 1  age_at_initial_pathologic_diagnosis ... tobacco_smoking_history total_dose
# 2  65                                  ... 3                       NA
# 3  48                                  ... 5                       NA
# 4  75                                  ... NA                      NA
# 5  71                                  ... NA                      NA
# 6  70                                  ... 1                       NA
# 7  55                                  ... 5                       NA
# 8  73                                  ... 3                       NA
# 9  73                                  ... 3                       NA
# 10 61                                  ... 1                       NA
# 11 55                                  ... 4                       NA
# 12 71                                  ... NA                      NA
# 13 43                                  ... 4                       NA
# 14 58                                  ... 1                       NA
# 15 60                                  ... NA                      NA
# 16 72                                  ... 1                       NA
# 17 56                                  ... 1                       NA
# 18 74                                  ... 5                       NA
# 19 76                                  ... 2                       NA
# 20 56                                  ... 2                       NA
#    total_dose_units tumor_tissue_site tumor_type withdrawn year_of_dcc_upload
# 1  total_dose_units tumor_tissue_site tumor_type withdrawn year_of_dcc_upload
# 2  NA               pancreas          primary    false     2016
# 3  NA               pancreas          primary    false     2016
# 4  NA               pancreas          primary    false     2016
# 5  NA               pancreas          primary    false     2016
# 6  NA               pancreas          primary    false     2016
# 7  NA               pancreas          primary    false     2016
# 8  NA               pancreas          primary    false     2016
# 9  NA               pancreas          primary    false     2016
# 10 NA               pancreas          primary    false     2016
# 11 NA               pancreas          primary    false     2016
# 12 NA               pancreas          primary    false     2016
# 13 NA               pancreas          primary    false     2016
# 14 NA               pancreas          primary    false     2016
# 15 NA               pancreas          primary    false     2016
# 16 NA               pancreas          primary    false     2016
# 17 NA               pancreas          primary    false     2016
# 18 NA               pancreas          primary    false     2016
# 19 NA               pancreas          primary    false     2016
# 20 NA               pancreas          primary    false     2016
#    year_of_form_completion year_of_initial_pathologic_diagnosis
# 1  year_of_form_completion year_of_initial_pathologic_diagnosis
# 2  2014                    2012
# 3  2014                    2012
# 4  2014                    2012
# 5  2014                    2012
# 6  2014                    2012
# 7  2014                    2012
# 8  2014                    2012
# 9  2014                    2012
# 10 2014                    2011
# 11 2014                    2011
# 12 2014                    2012
# 13 2014                    2013
# 14 2014                    2013
# 15 2014                    2013
# 16 2014                    2012
# 17 2014                    2012
# 18 2014                    2012
# 19 2014                    2010
# 20 2014                    2011
#    year_of_tobacco_smoking_onset
# 1  year_of_tobacco_smoking_onset
# 2  1962
# 3  NA
# 4  NA
# 5  NA
# 6  NA
# 7  NA
# 8  1960
# 9  1960
# 10 NA
# 11 1973
# 12 NA
# 13 1993
# 14 NA
# 15 NA
# 16 NA
# 17 NA
# 18 NA
# 19 NA
# 20 NA

# %%
head(t_expression_data,20)
# Out:
#    SLC35E2 A1BG   A1CF   A2BP1    A2LD1  A2ML1  A2M    A4GALT A4GNT    AAA1
# 1  SLC35E2 A1BG   A1CF   A2BP1    A2LD1  A2ML1  A2M    A4GALT A4GNT    AAA1
# 2  7.4500  6.4000 4.7000 -1.0000  7.5000 6.4000 14.300 10.600 8.8000   1.0000
# 3  8.1000  5.8000 5.7000 1.1000   6.8000 NaN    14.000 10.200 5.6000   -1.2000
# 4  7.2000  6.4000 3.0000 NaN      7.3000 10.800 13.100 10.100 0.20000  0.20000
# 5  8.0000  5.8000 5.1000 NaN      7.5000 4.1000 13.800 8.6000 3.2000   -0.10000
# 6  7.6500  6.7000 4.4000 0.10000  7.4000 9.3000 14.600 10.100 5.7000   NaN
# 7  8.1000  6.6000 4.2000 NaN      6.6000 9.8000 13.300 9.3000 2.6000   4.2000
# 8  8.2000  6.3000 1.6000 NaN      7.1000 6.2000 13.400 9.5000 5.1000   NaN
# 9  8.2000  6.5000 6.8000 1.7000   6.8000 3.8000 14.200 8.4000 6.9000   2.5000
# 10 7.5500  5.7000 6.0000 0.40000  8.0000 2.3000 13.900 8.4000 4.3000   1.4000
# 11 8.4500  6.3000 NaN    -1.5000  5.8000 10.100 11.900 7.9000 -0.50000 NaN
# 12 7.5000  6.8000 6.9000 1.6000   7.1000 2.7000 13.500 7.8000 9.4000   0.80000
# 13 7.5500  5.9000 4.6000 0.70000  7.7000 8.0000 14.600 8.7000 7.8000   0.70000
# 14 7.8000  5.7000 NaN    -0.90000 6.4000 NaN    14.700 10.300 NaN      NaN
# 15 8.1500  6.7000 6.2000 0.30000  6.5000 5.5000 14.400 10.500 5.8000   0.30000
# 16 8.7000  5.4000 4.5000 1.3000   6.9000 NaN    14.700 9.5000 4.5000   0.90000
# 17 8.0000  5.8000 3.1000 NaN      6.0000 9.8000 13.300 10.500 0.10000  NaN
# 18 6.5000  6.7000 5.7000 NaN      8.2000 NaN    13.500 9.0000 6.8000   NaN
# 19 6.5500  6.0000 5.3000 NaN      8.4000 1.7000 12.500 8.6000 4.5000   2.9000
# 20 8.1000  7.0000 1.2000 -0.10000 6.4000 7.5000 12.900 8.6000 -1.1000  NaN
#    ... ZWINT  ZXDA   ZXDB   ZXDC   ZYG11A   ZYG11B ZYX    ZZEF1  ZZZ3
# 1  ... ZWINT  ZXDA   ZXDB   ZXDC   ZYG11A   ZYG11B ZYX    ZZEF1  ZZZ3
# 2  ... 8.6000 6.2000 9.0000 9.9000 NaN      9.2000 12.900 10.100 9.3000
# 3  ... 8.8000 5.8000 8.5000 10.000 NaN      9.3000 12.400 9.8000 8.9000
# 4  ... 9.1000 3.9000 8.1000 10.000 -0.80000 9.4000 13.500 9.8000 9.2000
# 5  ... 8.9000 5.2000 8.5000 9.7000 1.9000   9.4000 12.500 9.7000 9.3000
# 6  ... 8.4000 5.9000 8.6000 9.9000 0.10000  9.3000 13.000 10.100 9.2000
# 7  ... 7.5000 5.7000 8.2000 10.600 0.30000  9.9000 12.200 10.400 9.6000
# 8  ... 7.9000 5.8000 8.8000 10.100 -0.70000 9.1000 12.900 9.7000 8.9000
# 9  ... 9.0000 5.8000 8.7000 9.9000 0.10000  9.5000 12.600 10.600 9.8000
# 10 ... 8.6000 6.4000 9.4000 9.8000 -1.2000  8.9000 12.700 10.000 8.8000
# 11 ... 9.2000 5.6000 9.0000 10.700 2.0000   8.3000 12.500 9.9000 8.6000
# 12 ... 9.0000 5.8000 8.8000 10.100 2.9000   9.5000 12.000 9.8000 9.5000
# 13 ... 8.1000 4.5000 8.7000 9.7000 NaN      9.2000 12.800 9.6000 9.2000
# 14 ... 10.000 4.9000 8.0000 9.5000 5.4000   9.6000 13.700 10.600 9.3000
# 15 ... 7.8000 5.9000 8.8000 10.200 0.30000  9.7000 12.500 10.400 9.3000
# 16 ... 7.7000 5.9000 8.7000 9.8000 NaN      10.100 13.600 11.000 9.2000
# 17 ... 9.2000 4.5000 8.2000 9.8000 1.7000   9.5000 12.800 9.5000 9.4000
# 18 ... 7.8000 4.0000 8.1000 9.9000 2.2000   8.5000 12.300 9.8000 8.1000
# 19 ... 9.5000 5.6000 9.0000 9.9000 NaN      8.7000 12.800 9.4000 8.5000
# 20 ... 8.5000 5.9000 8.3000 10.100 -1.1000  9.4000 12.600 10.000 9.3000
#    psiTPTE22
# 1  psiTPTE22
# 2  5.5000
# 3  4.5000
# 4  4.7000
# 5  6.4000
# 6  4.9000
# 7  5.0000
# 8  5.6000
# 9  5.1000
# 10 4.6000
# 11 3.6000
# 12 5.3000
# 13 5.0000
# 14 4.8000
# 15 5.7000
# 16 6.5000
# 17 4.8000
# 18 6.7000
# 19 4.1000
# 20 3.9000

# %%
outlier_fun <- function(df){
  for (columnindex in 1:ncol(df)){
    hist(df[,columnindex])
    print(grubbs.test(df[,columnindex]))
  }
}
outlier_fun(t_expression_data)
# Out:
# Error in `[.data.table`(df, , columnindex): j (the 2nd argument inside [...]) is a single symbol but column name 'columnindex' is not found. Perhaps you intended DT[, ..columnindex]. This difference to data.frame is deliberate and explained in FAQ 1.1.
# Traceback:
#
# 1. outlier_fun(t_expression_data)
# 2. hist(df[, columnindex])   # at line 3 of file <text>
# 3. df[, columnindex]   # at line 3 of file <text>
# 4. `[.data.table`(df, , columnindex)   # at line 3 of file <text>
# 5. stop("j (the 2nd argument inside [...]) is a single symbol but column name '",
#  .     jsubChar, "' is not found. Perhaps you intended DT[, ..",
#  .     jsubChar, "]. This difference to data.frame is deliberate and explained in FAQ 1.1.")

# %%
c(t_expression_data[,2])
# Out:
# $A1BG
#   [1] "A1BG"   "6.4000" "5.8000" "6.4000" "5.8000" "6.7000" "6.6000" "6.3000"
#   [9] "6.5000" "5.7000" "6.3000" "6.8000" "5.9000" "5.7000" "6.7000" "5.4000"
#  [17] "5.8000" "6.7000" "6.0000" "7.0000" "5.7000" "6.5000" "7.8000" "10.000"
#  [25] "7.3000" "6.1000" "7.2000" "6.5000" "7.1000" "6.5000" "9.3000" "9.5000"
#  [33] "9.7000" "8.6000" "8.0000" "8.5000" "6.2000" "9.0000" "6.7000" "5.3000"
#  [41] "5.1000" "6.9000" "5.1000" "4.5000" "6.2000" "6.3000" "5.8000" "6.5000"
#  [49] "7.0000" "5.6000" "6.6000" "7.6000" "6.4000" "6.2000" "7.1000" "6.2000"
#  [57] "5.9000" "2.8000" "6.0000" "8.2000" "4.9000" "6.8000" "5.5000" "5.6000"
#  [65] "6.8000" "6.2000" "7.5000" "5.7000" "6.4000" "6.0000" "7.2000" "7.1000"
#  [73] "7.2000" "6.9000" "6.9000" "6.5000" "6.7000" "5.7000" "7.1000" "5.9000"
#  [81] "7.5000" "6.2000" "5.2000" "3.6000" "4.8000" "6.3000" "4.6000" "6.5000"
#  [89] "4.7000" "5.7000" "5.1000" "6.3000" "5.4000" "5.5000" "5.2000" "5.6000"
#  [97] "5.5000" "7.9000" "6.5000" "6.4000" "5.0000" "6.8000" "7.3000" "6.9000"
# [105] "6.4000" "6.7000" "6.1000" "6.0000" "6.4000" "7.3000" "5.4000" "5.9000"
# [113] "6.0000" "4.7000" "5.1000" "3.8000" "4.6000" "5.3000" "5.5000" "5.8000"
# [121] "4.9000" "5.5000" "4.3000" "5.0000" "6.1000" "6.2000" "6.2000" "5.7000"
# [129] "5.7000" "5.7000" "7.2000" "5.9000" "6.9000" "5.1000" "7.7000" "6.5000"
# [137] "8.1000" "6.1000" "5.9000" "5.2000" "6.2000" "6.8000" "5.9000" "6.5000"
# [145] "6.8000" "7.2000" "7.5000" "7.8000" "7.4000" "5.9000" "7.7000" "6.3000"
# [153] "7.1000" "6.0000" "6.3000" "6.7000" "5.2000" "8.1000" "7.2000" "8.1000"
# [161] "6.2000" "7.4000" "6.6000" "7.6000" "5.3000" "6.3000" "6.9000" "6.9000"
# [169] "4.7000" "6.5000" "6.7000" "5.2000" "8.0000" "7.6000" "7.1000" "7.1000"
# [177] "6.7000" "7.0000" "6.9000" "7.1000" "7.3000" "7.9000" "6.0000" "6.9000"

# %% [markdown]
# ## References

# %% [markdown]
# #### 01 - Baek, B., Lee, H. Prediction of survival and recurrence in patients with pancreatic cancer by integrating multi-omics data. Sci Rep 10, 18951 (2020). https://doi.org/10.1038/s41598-020-76025-1
